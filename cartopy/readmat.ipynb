# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import scipy.io as scio
path = '/Users/zhengkai/Desktop/2020-at-home/AMOC_CBa_SGa/AMOC_1.mat'
data = scio.loadmat(path)
print(type(data)) 
print(data.keys())
data['SGa']

tmp=data['SGa']
print(type(tmp))
print(tmp)
print(len(tmp))
print(tmp[0])
a=tmp[0]
print(len(a))

fig, ax = plt.subplots(figsize=(10,4))
# ax.plot(data['CO2'][0][0:10000], data['SGa'][0][0:10000])

x=data['CO2'][0][801:10000]
y=data['SGa'][0][801:10000]
ax.plot(x, y,color='r')
ax.set(xlabel='CO2(ppm)', ylabel='AMOC',
       title='AMOC index')
ax.grid()
# Out:
# <class 'dict'>
# dict_keys(['__header__', '__version__', '__globals__', 'ace', 'SG', 'SGa', 'no_ber', 'CB', 'CBa', 'cbs', 'CO2_hosing', 'CO2_increasing', 'CO2', 'obs'])
# <class 'numpy.ndarray'>
# [[6.74369633 6.98876853 6.75745221 ... 7.3267609  6.44506923 6.7353369 ]]
# 1
# [6.74369633 6.98876853 6.75745221 ... 7.3267609  6.44506923 6.7353369 ]
# 10597
